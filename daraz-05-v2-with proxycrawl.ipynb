# %%
# this program will utilize the crawling api from this site https://proxycrawl.com/dashboard/api

# %%
import requests
import json
from bs4 import BeautifulSoup
import os
import pandas
import urllib3
import random

# %%
url="https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=69"

# %%
user_agent_list = [
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
]

for i in range(1,4):
    #Pick a random user agent
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    #Make the request
    res = requests.get(url,headers=headers)

    
print(res.status_code)
# Out:
# 200

# %%
#os.chdir(r'C:\Users\Farzad\Python')
#os.mkdir('daraz') 
#os.chdir(r'C:\Users\Farzad\Python\daraz')
#url="https://www.daraz.pk/bath/?ajax=true&page=1"
#ctgUrl="https://www.daraz.pk/bath/"
#ctgRes=requests.get(ctgUrl)
#res=requests.get(url)

# %%
#todos = json.loads(res.text)
#todos

# %%
#type(todos)

# %%
#listitems= todos['mods']['listItems'][0]
#listitems
# Out:
# {'name': 'Face Towels Pack of 10',
#  'nid': '168726472',
#  'icons': [],
#  'utLogMap': {'x_object_type': 'item',
#   'x_item_ids': '168726472',
#   'x_ad': '1',
#   'x_object_id': '168726472'},
#  'productUrl': '//www.daraz.pk/products/face-towels-pack-of-10-i168726472-s1338162003.html?search=1',
#  'image': 'https://static-01.daraz.pk/p/mdc/d728741b59f8acd6627ccdee2c68e696.png',
#  'originalPrice': '949.00',
#  'originalPriceShow': 'Rs. 949',
#  'price': '639.00',
#  'promotionId': 'null',
#  'priceShow': 'Rs. 639',
#  'discount': '-33%',
#  'ratingScore': '0',
#  'review': '0',
#  'installment': '',
#  'tItemType': 'nt_product',
#  'location': 'Pakistan',
#  'cheapest_sku': '168726472_PK-1338162003',
#  'sku': '168726472_PK',
#  'skus': [],
#  'description': [],
#  'brandId': '123306662',
#  'brandName': 'store360.pk',
#  'sellerId': '6005009136179',
#  'mainSellerId': '',
#  'sellerName': 'store360.pk',
#  'thumbs': [{'image': 'https://static-01.daraz.pk/p/mdc/d728741b59f8acd6627ccdee2c68e696.png',
#    'productUrl': '//www.daraz.pk/products/face-towels-pack-of-10-i168726472-s1338162003.html?search=1',
#    'sku': '168726472_PK',
#    'skuId': '1338162003'}],
#  'restrictedAge': 0,
#  'categories': [10000335, 10000341, 10000390],
#  'clickTrace': 'query:;nid:168726472;src:LazadaMainSrp;rn:94e606785ed8bed396906d490894b169;region:pk;sku:168726472_PK;price:639.00;client:desktop;supplier_id:6005009136179;asc_category_id:10000390;item_id:168726472;sku_id:1338162003;shop_id:296569',
#  'addToCartSkus': [{'sku': '168726472_PK-1338162003',
#    'skuId': '1338162003',
#    'count': 0}],
#  'itemId': '168726472',
#  'skuId': '1338162003',
#  'inStock': True,
#  'isAD': 0}

# %%
#len(listitems)

# %%
#type(listitems)

# %%
#pageNo= int(todos['mainInfo']['page'])
#pageNo

# %%
#listitems[0]

# %%
#listitems[0]['originalPrice']

# %%
#listitems[0]['productUrl'].replace("//www", "www")

# %%
#listitems[0]['itemId']

# %%
#listitems[15]['review']

# %% [markdown]
# for i in range(1,40):
#     print(listitems[i]['name'])
#     print(listitems[i]['productUrl'])
#     print(listitems[i]['priceShow'])
#     try: print(listitems[i]['discount'])
#     except: print(None)
#     print(listitems[i]['ratingScore'])
#     print(listitems[i]['inStock'])
#     print(listitems[i]['location'])
#     print(listitems[i]['image'])
#     print(listitems[i]['sellerName'])
#     print(listitems[i]['brandName'])
#     print(listitems[i]['sellerId'])
#     print()

# %%
from time import sleep
from random import randint

# %%
l=[]
base_url=("https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=")
part_url=("&rating=3")
#for i in range(1,4):
    #Pick a random user agent
    #user_agent = random.choice(user_agent_list)
    #Set the headers 
    #headers = {'User-Agent': user_agent}
    #Make the request
    #res = requests.get(base_url,headers=headers)

#p+=pageNo
p=102+1
#pageNo= int(todos['mainInfo']['page'])
for page in range(68,p):
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    print(base_url+str(page)+part_url)
    res=requests.get(base_url+str(page)+part_url,headers=headers)
    print("Request #%d\nUser-Agent Sent:%s\n\nHeaders Recevied by HTTPBin:"%(i,user_agent))
    print(res.status_code)
    #print(site.status_code)
    #soup=BeautifulSoup(site.content, "html.parser")
    #print(soup.prettify())
    #all=soup.find_all("div", {"class": ["product-info"]})
    #len(all)
    todos = json.loads(res.text)
    listitems= todos['mods']['listItems']
    pageSize= todos['mainInfo']['pageSize']
    #p=p+1
    #sleep(randint(12,20))

    for i in range(0, int(pageSize)):
        d={}
        d['name']=listitems[i]['name']
        d['productUrl']=listitems[i]['productUrl'].replace("//www", "www")
        try: d['originalPrice']=listitems[i]['originalPrice']
        except: d['originalPrice']=None
        try: d['price']=listitems[i]['price']
        except: d['price']=None
        try: d['discount']=listitems[i]['discount']
        except:d['discount']= None
        try: d['ratingScore']=listitems[i]['ratingScore']
        except: d['ratingScore']=None
        try: d['review']=listitems[i]['review']
        except: d['review']=None            
        try: d['inStock']=listitems[i]['inStock']
        except: d['inStock']=None
        try: d['location']=listitems[i]['location']
        except: d['location']=None
        d['image']=listitems[i]['image']
        d['Seller Name']=listitems[i]['sellerName']
        try: d['Brand Name']=listitems[i]['brandName']
        except: d['Brand Name']=None
        d['Seller Id']=listitems[i]['sellerId']
        try: d['Item Id']=listitems[i]['itemId']
        except: d['Item Id']=None
        l.append(d)
# Out:
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=68&rating=3
# Request #3
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=69&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=70&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=71&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=72&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=73&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=74&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=75&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=76&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=77&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=78&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=79&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=80&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=81&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=82&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=83&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=84&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=85&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=86&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=87&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=88&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=89&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=90&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=91&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=92&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=93&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=94&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=95&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=96&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=97&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=98&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=99&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=100&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=101&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://api.proxycrawl.com/?token=_cibYxk0on03pomPMVd0fw&url=https://www.daraz.pk/womens-fashion/?ajax=true&page=102&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200

# %%
len(l)
# Out:
# 1400

# %%
#l

# %%
df=pandas.DataFrame(l)

# %%
df
# Out:
#                                                    name  \
# 0     White Crazy Cat Lady Printed Sweat shirt For W...
# 1     White I love Nutella Printed Sweat Shirt For W...
# 2            White i hate morning sweat shirt For Women
# 3      Dark Grey Pearl Embellished Sweatshirt For Women
# 4            FRIENDS Printed Sweatshirt Black For Women
# ...                                                 ...
# 1395                ROYAL BLUE MARVEL HOODIE FOR womens
# 1396          Gray Rabbit Printed Sweat Shirt For Women
# 1397                 NIRVANA Sweat Shirt For Her womens
# 1398  Marshmello 100% Fleece Round-necked womens pri...
# 1399  Sober Wear Fleece Cotton Pull Over Sweatshirt ...
#
#                                              productUrl originalPrice   price  \
# 0     www.daraz.pk/products/white-crazy-cat-lady-pri...        999.00  699.00
# 1     www.daraz.pk/products/white-i-love-nutella-pri...        999.00  699.00
# 2     www.daraz.pk/products/white-i-hate-morning-swe...        999.00  699.00
# 3     www.daraz.pk/products/dark-grey-pearl-embellis...        999.00  899.00
# 4     www.daraz.pk/products/friends-printed-sweatshi...        999.00  699.00
# ...                                                 ...           ...     ...
# 1395  www.daraz.pk/products/royal-blue-marvel-hoodie...        999.00  799.00
# 1396  www.daraz.pk/products/gray-rabbit-printed-swea...        999.00  699.00
# 1397  www.daraz.pk/products/nirvana-sweat-shirt-for-...        999.00  699.00
# 1398  www.daraz.pk/products/marshmello-100-fleece-ro...        999.00  699.00
# 1399  www.daraz.pk/products/sober-wear-fleece-cotton...        999.00  699.00
#
#      discount ratingScore review  inStock  location  \
# 0        -30%           0      0     True  Pakistan
# 1        -30%           0      0     True  Pakistan
# 2        -30%           0      0     True  Pakistan
# 3        -10%           0      0     True  Pakistan
# 4        -30%           0      0     True  Pakistan
# ...       ...         ...    ...      ...       ...
# 1395     -20%           0      0     True  Pakistan
# 1396     -30%           0      0     True  Pakistan
# 1397     -30%           0      0     True  Pakistan
# 1398     -30%           0      0     True  Pakistan
# 1399     -30%           0      0     True  Pakistan
#
#                                                   image     Seller Name  \
# 0     https://static-01.daraz.pk/p/5cc422efe10bc36ad...    Fashion Nova
# 1     https://static-01.daraz.pk/p/810b40b03c2a437a3...    Fashion Nova
# 2     https://static-01.daraz.pk/p/49741975ec6f9f6fa...    Fashion Nova
# 3     https://static-01.daraz.pk/p/9a1e17b4cb98ea616...    Fashion Nova
# 4     https://static-01.daraz.pk/p/00d192221c0794f27...    Fashion Nova
# ...                                                 ...             ...
# 1395  https://static-01.daraz.pk/p/90481f345ff8d2345...  hassan brother
# 1396  https://static-01.daraz.pk/p/9bfadeec043144178...    H&B FASHIONS
# 1397  https://static-01.daraz.pk/p/451bef1e6148e1cdc...         Mr. Ace
# 1398  https://static-01.daraz.pk/p/3dd8348d5ecdffb2a...  7 star apparel
# 1399  https://static-01.daraz.pk/p/fccfe68a76e8595d5...          iFixis
#
#           Brand Name      Seller Id    Item Id
# 0            AceCart        1058096  168700525
# 1            AceCart        1058096  168706287
# 2            AceCart        1058096  168706286
# 3            AceCart        1058096  168700462
# 4            AceCart        1058096  168700503
# ...              ...            ...        ...
# 1395         AceCart        1037078  169038553
# 1396         AceCart  6005007783146  167818553
# 1397         AceCart        1087933  167432553
# 1398  7 star apparel        1101018  167828552
# 1399         AceCart  6005010723229  167444552
#
# [1400 rows x 14 columns]

# %%
df.to_csv("daraz/women/Daraz_rating3_68to102_6sept20.csv")

# %%
#pageSize= int(todos['mainInfo']['pageSize'])
#pageSize

# %%
#pageNo= todos['mainInfo']['page']
#pageNo

# %%
#xUrl=("https://www.daraz.pk/bath/?ajax=true&page=")

# %%
#partUrl=("&rating=3")
#numUrl=3

# %%
#nUrl=(xUrl+str(numUrl)+partUrl)
#print(nUrl)
