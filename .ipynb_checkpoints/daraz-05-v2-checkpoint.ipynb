# %%
import requests
import json
from bs4 import BeautifulSoup
import os
import pandas
import random
user_agent_list = [
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
]
url="https://www.daraz.pk/bath/?ajax=true&page=1&rating=3"
for i in range(1,4):
    #Pick a random user agent
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    #Make the request
    res = requests.get(url,headers=headers)

os.chdir(r'C:\Users\Farzad\Python')
#os.mkdir('daraz') 
#os.chdir(r'C:\Users\Farzad\Python\daraz')
#url="https://www.daraz.pk/bath/?ajax=true&page=1"
ctgUrl="https://www.daraz.pk/bath/"
ctgRes=requests.get(ctgUrl)
#res=requests.get(url)

print(res.status_code)
# Out:
# 200

# %%
#print("Request #%d\nUser-Agent Sent:%s\n\nHeaders Recevied by HTTPBin:"%(i,user_agent))

# %%
#from fake_useragent import UserAgent

# %%
#ua = UserAgent()

# %%
#print(ua)

# %%
#soup=BeautifulSoup(ctgRes.content, "html.parser")

# %%
#pageend=soup.find("class", "ant-pagination")
#print(pageend)

# %%
#res.content

# %%
todos = json.loads(res.text)
#todos

# %%
#type(todos)

# %%
listitems= todos['mods']['listItems']
#listitems

# %%
#len(listitems)

# %%
#type(listitems)

# %%
#pageNo= int(todos['mainInfo']['page'])
#pageNo

# %%
listitems[0]
# Out:
# {'name': 'Imported Liquid Soap Dispenser 400ml - Imenab (Gloria)',
#  'nid': '146504211',
#  'icons': [{'domClass': 'freeShipping',
#    'text': 'FreeShipping',
#    'alias': 'FsAlias',
#    'type': 'img',
#    'group': '2',
#    'showType': '0',
#    'order': 0,
#    'font-size': 0}],
#  'utLogMap': {'x_object_type': 'item',
#   'x_item_ids': '146504211',
#   'x_ad': '1',
#   'x_object_id': '146504211'},
#  'productUrl': '//www.daraz.pk/products/imported-liquid-soap-dispenser-400ml-imenab-gloria-i146504211-s1309338853.html?search=1',
#  'image': 'https://static-01.daraz.pk/p/21e1437d4987c8b6bbd650d0c21d5a98.jpg',
#  'originalPrice': '1499.00',
#  'originalPriceShow': 'Rs. 1,499',
#  'price': '1149.00',
#  'promotionId': 'null',
#  'priceShow': 'Rs. 1,149',
#  'discount': '-23%',
#  'ratingScore': '4',
#  'review': '1',
#  'installment': '',
#  'tItemType': 'nt_product',
#  'location': 'Pakistan',
#  'cheapest_sku': '146504211_PK-1309338853',
#  'sku': '146504211_PK',
#  'skus': [],
#  'description': [],
#  'brandId': '121186651',
#  'brandName': 'Suriya eShop',
#  'sellerId': '1149217',
#  'mainSellerId': '',
#  'sellerName': 'Suriya eShop',
#  'thumbs': [{'image': 'https://static-01.daraz.pk/p/21e1437d4987c8b6bbd650d0c21d5a98.jpg',
#    'productUrl': '//www.daraz.pk/products/imported-liquid-soap-dispenser-400ml-imenab-gloria-i146504211-s1309338853.html?search=1',
#    'sku': '146504211_PK',
#    'skuId': '1309338853'}],
#  'restrictedAge': 0,
#  'categories': [10000335, 10000341, 10000381],
#  'clickTrace': 'query:;nid:146504211;src:LazadaMainSrp;rn:42bca1530d5e2c0ff272c4cecc75be0c;region:pk;sku:146504211_PK;price:1149.00;client:desktop;supplier_id:1149217;asc_category_id:10000381;item_id:146504211;sku_id:1309338853;shop_id:258118',
#  'addToCartSkus': [{'sku': '146504211_PK-1309338853',
#    'skuId': '1309338853',
#    'count': 0}],
#  'itemId': '146504211',
#  'skuId': '1309338853',
#  'inStock': True,
#  'isAD': 0}

# %%
#listitems[0]['originalPrice']

# %%
#listitems[0]['productUrl'].replace("//www", "www")

# %%
#listitems[0]['itemId']

# %%
#listitems[15]['review']

# %%
#df=pd.read(todos)

# %%
#m.to_csv("Output.csv")

# %%
#import pandas
#df=pandas.DataFrame(res)

# %%
#df

# %% [markdown]
# for i in range(1,40):
#     print(listitems[i]['name'])
#     print(listitems[i]['productUrl'])
#     print(listitems[i]['priceShow'])
#     try: print(listitems[i]['discount'])
#     except: print(None)
#     print(listitems[i]['ratingScore'])
#     print(listitems[i]['inStock'])
#     print(listitems[i]['location'])
#     print(listitems[i]['image'])
#     print(listitems[i]['sellerName'])
#     print(listitems[i]['brandName'])
#     print(listitems[i]['sellerId'])
#     print()

# %%
from time import sleep
from random import randint

# %%
l=[]
base_url=("https://www.daraz.pk/bath/?ajax=true&page=")
part_url=("&rating=3")
#for i in range(1,4):
    #Pick a random user agent
    #user_agent = random.choice(user_agent_list)
    #Set the headers 
    #headers = {'User-Agent': user_agent}
    #Make the request
    #res = requests.get(base_url,headers=headers)

#p+=pageNo
p=75+1
#pageNo= int(todos['mainInfo']['page'])
for page in range(1,p):
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    print(base_url+str(page)+part_url)
    res=requests.get(base_url+str(page)+part_url,headers=headers)
    print("Request #%d\nUser-Agent Sent:%s\n\nHeaders Recevied by HTTPBin:"%(i,user_agent))
    print(res.status_code)
    #print(site.status_code)
    #soup=BeautifulSoup(site.content, "html.parser")
    #print(soup.prettify())
    #all=soup.find_all("div", {"class": ["product-info"]})
    #len(all)
    todos = json.loads(res.text)
    listitems= todos['mods']['listItems']
    pageSize= todos['mainInfo']['pageSize']
    #p=p+1
    sleep(randint(10,18))

    for i in range(0, int(pageSize)):
        d={}
        d['name']=listitems[i]['name']
        d['productUrl']=listitems[i]['productUrl'].replace("//www", "www")
        try: d['originalPrice']=listitems[i]['originalPrice']
        except: d['originalPrice']=None
        try: d['price']=listitems[i]['price']
        except: d['price']=None
        try: d['discount']=listitems[i]['discount']
        except:d['discount']= None
        try: d['ratingScore']=listitems[i]['ratingScore']
        except: d['ratingScore']=None
        try: d['review']=listitems[i]['review']
        except: d['review']=None            
        try: d['inStock']=listitems[i]['inStock']
        except: d['inStock']=None
        try: d['location']=listitems[i]['location']
        except: d['location']=None
        d['image']=listitems[i]['image']
        d['Seller Name']=listitems[i]['sellerName']
        try: d['Brand Name']=listitems[i]['brandName']
        except: d['Brand Name']=None
        d['Seller Id']=listitems[i]['sellerId']
        try: d['Item Id']=listitems[i]['itemId']
        except: d['Item Id']=None
        l.append(d)
# Out:
# https://www.daraz.pk/bath/?ajax=true&page=1&rating=3
# Request #3
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=2&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=3&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=4&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=5&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=6&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=7&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=8&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=9&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=10&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=11&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=12&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=13&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=14&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=15&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=16&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=17&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=18&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=19&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=20&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=21&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=22&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=23&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=24&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=25&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=26&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=27&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=28&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=29&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=30&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=31&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=32&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=33&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=34&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=35&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=36&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=37&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=38&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=39&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=40&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=41&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=42&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=43&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=44&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=45&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=46&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=47&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=48&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=49&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=50&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=51&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=52&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=53&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=54&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=55&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=56&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=57&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=58&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=59&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=60&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=61&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=62&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=63&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=64&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=65&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=66&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=67&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=68&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=69&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=70&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=71&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=72&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=73&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=74&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200
# https://www.daraz.pk/bath/?ajax=true&page=75&rating=3
# Request #39
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36
#
# Headers Recevied by HTTPBin:
# 200

# %%
len(l)
# Out:
# 3000

# %%
#l

# %%
df=pandas.DataFrame(l)

# %%
df
# Out:
#                                                    name  \
# 0     Imported Liquid Soap Dispenser 400ml - Imenab ...
# 1                               Pack Of 8 Wonder Hanger
# 2     Multi-Purpose Scarf/Belt/Tie/Dupata Hanging Or...
# 3     Soap Dish Self Draining Soap Case Holder-Silic...
# 4     Bath Curtains Waterproof Shower Curtain With 1...
# ...                                                 ...
# 2995  Bath Stool Square Millat (SPRING SERIES) Pack ...
# 2996  Bath Stool Round Millat (SPRING SERIES) Pack of 2
# 2997        Large Plastic Over the Shower Caddy Frosted
# 2998  Imported 100% Accurate Strong Glass Electronic...
# 2999  Imported 100% Accurate Strong Glass Electronic...
#
#                                              productUrl originalPrice  \
# 0     www.daraz.pk/products/imported-liquid-soap-dis...       1499.00
# 1     www.daraz.pk/products/pack-of-8-wonder-hanger-...        650.00
# 2     www.daraz.pk/products/multi-purpose-scarfbeltt...          None
# 3     www.daraz.pk/products/soap-dish-self-draining-...        200.00
# 4     www.daraz.pk/products/bath-curtains-waterproof...        599.00
# ...                                                 ...           ...
# 2995  www.daraz.pk/products/bath-stool-square-millat...          None
# 2996  www.daraz.pk/products/bath-stool-round-millat-...          None
# 2997  www.daraz.pk/products/large-plastic-over-the-s...       1000.00
# 2998  www.daraz.pk/products/imported-100-accurate-st...          None
# 2999  www.daraz.pk/products/imported-100-accurate-st...          None
#
#         price discount ratingScore review  inStock  location  \
# 0     1149.00     -23%           4      1     True  Pakistan
# 1      190.00     -71%     4.16667      6     True  Pakistan
# 2      400.00     None        3.25      4     True  Pakistan
# 3      150.00     -25%           5      1     True  Pakistan
# 4      519.00     -13%           4      3     True  Pakistan
# ...       ...      ...         ...    ...      ...       ...
# 2995   640.00     None           5      1     True  Pakistan
# 2996   640.00     None           5      2     True  Pakistan
# 2997   600.00     -40%           5      1     True  Pakistan
# 2998  1395.00     None     4.52941     17     True  Pakistan
# 2999  1425.00     None         4.5      6     True  Pakistan
#
#                                                   image  \
# 0     https://static-01.daraz.pk/p/21e1437d4987c8b6b...
# 1     https://static-01.daraz.pk/p/b1a34bef69f709ff5...
# 2     https://static-01.daraz.pk/original/cf2a2d15ce...
# 3     https://static-01.daraz.pk/p/mdc/f2ff358bb63d0...
# 4     https://static-01.daraz.pk/p/2defbdb8e7d87917b...
# ...                                                 ...
# 2995  https://static-01.daraz.pk/p/mdc/ee282acbfb109...
# 2996  https://static-01.daraz.pk/p/mdc/4b27fd7a524f1...
# 2997  https://static-01.daraz.pk/p/f60dd6c1c5a76a20c...
# 2998  https://static-01.daraz.pk/p/6897906c0afde5cbd...
# 2999  https://static-01.daraz.pk/p/a2b1db93d0fb59d17...
#
#                      Seller Name               Brand Name      Seller Id  \
# 0                   Suriya eShop             Suriya eShop        1149217
# 1         365Cosmetics (Karachi)             365Cosmetics          14427
# 2             Dealizle (Karachi)             365 Products          20567
# 3                         Velvet                My Velvet  6005010567045
# 4                   BodyNFashion             BodyNFashion        1100646
# ...                          ...                      ...            ...
# 2995     Millat Plastic Products  Millat Plastic Products        1142943
# 2996     Millat Plastic Products  Millat Plastic Products        1142943
# 2997  AYaan chase mart (Karachi)         Ayaan chase mart          10999
# 2998        Lahore Cart (Lahore)                 Imported          11842
# 2999        Lahore Cart (Lahore)                 Imported          11842
#
#         Item Id
# 0     146504211
# 1       8128249
# 2     100036396
# 3     165004075
# 4     130863350
# ...         ...
# 2995  134219111
# 2996  134191926
# 2997  132123057
# 2998  102644239
# 2999  105612382
#
# [3000 rows x 14 columns]

# %%
df.to_csv("daraz/bath/Daraz_rating3_4sept20.csv")

# %%
#pageSize= int(todos['mainInfo']['pageSize'])
#pageSize

# %%
#pageNo= todos['mainInfo']['page']
#pageNo

# %%
#xUrl=("https://www.daraz.pk/bath/?ajax=true&page=")

# %%
#partUrl=("&rating=3")
#numUrl=3

# %%
#nUrl=(xUrl+str(numUrl)+partUrl)
#print(nUrl)
